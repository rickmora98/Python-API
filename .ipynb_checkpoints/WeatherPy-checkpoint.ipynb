# %% [markdown]
# # WeatherPy

# %% [markdown]
# #### Library Dependencies and Setup

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from time import sleep
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ----
# ## Get Weather for Cities Around The World

# %% [markdown]
# #### Generate Cities List
# * Generate random global coordinates.
# * Use CityPy to get the names of cities closest to the random coordinates.
# * Make sure that each city is not duplicated in the list.
# * Make sure there are at least 500 cities in the list.

# %%
# Create lists for holding city names and city coordinates
citylist = []
coordinateslist = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
coordinateslist = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in coordinateslist:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in citylist:
        citylist.append(city)

# Print the city count to confirm sufficient count (should be more than 500)
if len(citylist) < 500:
    print("Not enough cities were generated.")
    print("Please re-run this section.")
else:
    print(f"Number of cities generated: {len(citylist)}")
    print("Continue with next section.")
# Out:
# 582

# %% [markdown]
# #### Get Weather for Each City in List
# * Use the OpenWeather API to get the weather for each city.
# * Because the process takes several minutes, print a status for each city as it is processed.
# * If OpenWeather does not have weather for a city, print a message indicating this.
# * Print a message when all cities have been processed with the number of successful retrievals.

# %%
# Define openweather base query string
units = "imperial"
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# Create lists to hold the weather data
stationlats = []
stationlngs = []
cities = []
countries = []
maxtemps = []
humidities = []
cloudiness = []
windspeeds = []
dates = []

# Set time delay for repetitive API calls to OpenWeather
# OpenWeather has a 60 queries per minute limit
timedelay = 0.5

# Display start message
print("Weather Data Retrieval In Progress")
print("  (This will take a few minues.)")
print("----------------------------------")

# Loop through all cities in citylist and get their respective weather info from OpenWeather
# Display status message
for index, city in enumerate(citylist, start=1):
    response = requests.get(query_url + city).json()
    sleep(timedelay)  # Time delay to not exceed 60 query per minute limit
    try:
        print(f"Getting weather in city # {index} ({city})")
        stationlats.append(response["coord"]["lat"])
        stationlngs.append(response["coord"]["lon"])
        maxtemps.append(response["main"]["temp_max"])
        humidities.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windspeeds.append(response["wind"]["speed"])
        countries.append(response["sys"]["country"])
        dates.append(response["dt"])
        cities.append(city)
    except:
        print("City not found. Skipping...")
    
# Display finished message
print("-------------------------------")
print("Weather Data Retrieval Complete")
print(f"Weather found for {len(dates)} out of {len(citylist)} cities")
print("-------------------------------")
# Out:
# Weather Data Retrieval In Progress
#   (This will take a few minues.)
# ----------------------------------
# Getting weather in city # 1 (omboue)
# Getting weather in city # 2 (kodiak)
# Getting weather in city # 3 (hobart)
# Getting weather in city # 4 (illoqqortoormiut)
# City not found. Skipping...
# Getting weather in city # 5 (nyurba)
# Getting weather in city # 6 (chuy)
# Getting weather in city # 7 (samarai)
# Getting weather in city # 8 (hamilton)
# Getting weather in city # 9 (san policarpo)
# Getting weather in city # 10 (ribeira grande)
# Getting weather in city # 11 (karratha)
# Getting weather in city # 12 (ushuaia)
# Getting weather in city # 13 (farim)
# Getting weather in city # 14 (vaini)
# Getting weather in city # 15 (hilo)
# Getting weather in city # 16 (tombouctou)
# Getting weather in city # 17 (tsihombe)
# City not found. Skipping...
# Getting weather in city # 18 (tiarei)
# Getting weather in city # 19 (hualmay)
# Getting weather in city # 20 (college)
# Getting weather in city # 21 (rikitea)
# Getting weather in city # 22 (atuona)
# Getting weather in city # 23 (esperance)
# Getting weather in city # 24 (bilibino)
# Getting weather in city # 25 (pokhara)
# Getting weather in city # 26 (taolanaro)
# City not found. Skipping...
# Getting weather in city # 27 (bluff)
# Getting weather in city # 28 (yanan)
# City not found. Skipping...
# Getting weather in city # 29 (yellowknife)
# Getting weather in city # 30 (lagos)
# Getting weather in city # 31 (katsuura)
# Getting weather in city # 32 (sayyan)
# Getting weather in city # 33 (leningradskiy)
# Getting weather in city # 34 (jamestown)
# Getting weather in city # 35 (provideniya)
# Getting weather in city # 36 (nhulunbuy)
# Getting weather in city # 37 (arman)
# Getting weather in city # 38 (nizhneyansk)
# City not found. Skipping...
# Getting weather in city # 39 (starkville)
# Getting weather in city # 40 (ancud)
# Getting weather in city # 41 (te anau)
# Getting weather in city # 42 (fortuna)
# Getting weather in city # 43 (atikokan)
# Getting weather in city # 44 (castro)
# Getting weather in city # 45 (amderma)
# City not found. Skipping...
# Getting weather in city # 46 (punta arenas)
# Getting weather in city # 47 (ugarcin)
# City not found. Skipping...
# Getting weather in city # 48 (dzhebariki-khaya)
# Getting weather in city # 49 (georgetown)
# Getting weather in city # 50 (port moresby)
# Getting weather in city # 51 (port alfred)
# Getting weather in city # 52 (kapaa)
# Getting weather in city # 53 (rucheng)
# Getting weather in city # 54 (tres arroyos)
# Getting weather in city # 55 (luba)
# Getting weather in city # 56 (fevralsk)
# City not found. Skipping...
# Getting weather in city # 57 (aklavik)
# Getting weather in city # 58 (bredasdorp)
# Getting weather in city # 59 (pisco)
# Getting weather in city # 60 (yulara)
# Getting weather in city # 61 (carnarvon)
# Getting weather in city # 62 (hermanus)
# Getting weather in city # 63 (attawapiskat)
# City not found. Skipping...
# Getting weather in city # 64 (mataura)
# Getting weather in city # 65 (east london)
# Getting weather in city # 66 (nome)
# Getting weather in city # 67 (gat)
# Getting weather in city # 68 (iracoubo)
# Getting weather in city # 69 (yaan)
# Getting weather in city # 70 (bardsir)
# Getting weather in city # 71 (preobrazheniye)
# Getting weather in city # 72 (ahipara)
# Getting weather in city # 73 (fairbanks)
# Getting weather in city # 74 (upernavik)
# Getting weather in city # 75 (kiruna)
# Getting weather in city # 76 (kruisfontein)
# Getting weather in city # 77 (broken hill)
# Getting weather in city # 78 (butaritari)
# Getting weather in city # 79 (petresti)
# Getting weather in city # 80 (high level)
# Getting weather in city # 81 (lebu)
# Getting weather in city # 82 (busselton)
# Getting weather in city # 83 (san patricio)
# Getting weather in city # 84 (arraial do cabo)
# Getting weather in city # 85 (coquimbo)
# Getting weather in city # 86 (samusu)
# City not found. Skipping...
# Getting weather in city # 87 (semey)
# Getting weather in city # 88 (varda)
# Getting weather in city # 89 (vardo)
# Getting weather in city # 90 (saint george)
# Getting weather in city # 91 (khatanga)
# Getting weather in city # 92 (hami)
# Getting weather in city # 93 (luwuk)
# Getting weather in city # 94 (pontianak)
# Getting weather in city # 95 (bengkulu)
# Getting weather in city # 96 (nikolskoye)
# Getting weather in city # 97 (nanortalik)
# Getting weather in city # 98 (wattegama)
# Getting weather in city # 99 (hunza)
# City not found. Skipping...
# Getting weather in city # 100 (cidreira)
# Getting weather in city # 101 (new norfolk)
# Getting weather in city # 102 (brokopondo)
# Getting weather in city # 103 (hithadhoo)
# Getting weather in city # 104 (mar del plata)
# Getting weather in city # 105 (qaanaaq)
# Getting weather in city # 106 (washougal)
# Getting weather in city # 107 (sharan)
# Getting weather in city # 108 (mount isa)
# Getting weather in city # 109 (mutsamudu)
# City not found. Skipping...
# Getting weather in city # 110 (sri aman)
# Getting weather in city # 111 (albany)
# Getting weather in city # 112 (ostrovnoy)
# Getting weather in city # 113 (mys shmidta)
# City not found. Skipping...
# Getting weather in city # 114 (port hardy)
# Getting weather in city # 115 (killybegs)
# Getting weather in city # 116 (coihaique)
# Getting weather in city # 117 (tuktoyaktuk)
# Getting weather in city # 118 (la ronge)
# Getting weather in city # 119 (lujan)
# Getting weather in city # 120 (cape town)
# Getting weather in city # 121 (tocopilla)
# Getting weather in city # 122 (mariakani)
# Getting weather in city # 123 (bokoro)
# Getting weather in city # 124 (along)
# Getting weather in city # 125 (ilulissat)
# Getting weather in city # 126 (sharqpur)
# Getting weather in city # 127 (mitchell)
# Getting weather in city # 128 (kotka)
# Getting weather in city # 129 (gimli)
# Getting weather in city # 130 (pangnirtung)
# Getting weather in city # 131 (victoria)
# Getting weather in city # 132 (chissamba)
# Getting weather in city # 133 (cape coast)
# Getting weather in city # 134 (irtyshskiy)
# Getting weather in city # 135 (kavieng)
# Getting weather in city # 136 (saint-philippe)
# Getting weather in city # 137 (porto murtinho)
# Getting weather in city # 138 (plavinas)
# Getting weather in city # 139 (norman wells)
# Getting weather in city # 140 (yamada)
# Getting weather in city # 141 (port hawkesbury)
# Getting weather in city # 142 (raymond)
# Getting weather in city # 143 (yumen)
# Getting weather in city # 144 (whitehorse)
# Getting weather in city # 145 (buraydah)
# Getting weather in city # 146 (katobu)
# Getting weather in city # 147 (krasnoselkup)
# Getting weather in city # 148 (flinders)
# Getting weather in city # 149 (bethel)
# Getting weather in city # 150 (ponta do sol)
# Getting weather in city # 151 (kieta)
# Getting weather in city # 152 (luderitz)
# Getting weather in city # 153 (arteaga)
# Getting weather in city # 154 (barentsburg)
# City not found. Skipping...
# Getting weather in city # 155 (souillac)
# Getting weather in city # 156 (klaksvik)
# Getting weather in city # 157 (luwingu)
# Getting weather in city # 158 (ayan)
# Getting weather in city # 159 (chokurdakh)
# Getting weather in city # 160 (airai)
# Getting weather in city # 161 (morgan city)
# Getting weather in city # 162 (merauke)
# Getting weather in city # 163 (barabai)
# Getting weather in city # 164 (joaquim nabuco)
# Getting weather in city # 165 (toliary)
# City not found. Skipping...
# Getting weather in city # 166 (aranos)
# Getting weather in city # 167 (deputatskiy)
# Getting weather in city # 168 (avarua)
# Getting weather in city # 169 (saleaula)
# City not found. Skipping...
# Getting weather in city # 170 (bilma)
# Getting weather in city # 171 (matagami)
# Getting weather in city # 172 (cabo san lucas)
# Getting weather in city # 173 (tasiilaq)
# Getting weather in city # 174 (padang)
# Getting weather in city # 175 (yelizovo)
# Getting weather in city # 176 (moussoro)
# Getting weather in city # 177 (sala)
# Getting weather in city # 178 (codrington)
# Getting weather in city # 179 (pacific grove)
# Getting weather in city # 180 (dali)
# Getting weather in city # 181 (falam)
# Getting weather in city # 182 (pasighat)
# Getting weather in city # 183 (tromso)
# Getting weather in city # 184 (belyy yar)
# Getting weather in city # 185 (riyadh)
# Getting weather in city # 186 (saint joseph)
# Getting weather in city # 187 (muskegon)
# Getting weather in city # 188 (manta)
# Getting weather in city # 189 (avera)
# Getting weather in city # 190 (channel-port aux basques)
# Getting weather in city # 191 (mahebourg)
# Getting weather in city # 192 (puerto ayora)
# Getting weather in city # 193 (coahuayana)
# Getting weather in city # 194 (udomlya)
# Getting weather in city # 195 (lavrentiya)
# Getting weather in city # 196 (nouadhibou)
# Getting weather in city # 197 (wangkui)
# Getting weather in city # 198 (colares)
# Getting weather in city # 199 (buala)
# Getting weather in city # 200 (santander)
# Getting weather in city # 201 (vaitupu)
# City not found. Skipping...
# Getting weather in city # 202 (fort frances)
# Getting weather in city # 203 (hvolsvollur)
# Getting weather in city # 204 (san quintin)
# Getting weather in city # 205 (shingu)
# Getting weather in city # 206 (foix)
# Getting weather in city # 207 (egvekinot)
# Getting weather in city # 208 (miri)
# Getting weather in city # 209 (tiksi)
# Getting weather in city # 210 (linjiang)
# Getting weather in city # 211 (sarab)
# Getting weather in city # 212 (saint-francois)
# Getting weather in city # 213 (lata)
# Getting weather in city # 214 (rabak)
# Getting weather in city # 215 (ciudad bolivar)
# Getting weather in city # 216 (abu dhabi)
# Getting weather in city # 217 (noumea)
# Getting weather in city # 218 (nam som)
# Getting weather in city # 219 (kefamenanu)
# Getting weather in city # 220 (maputo)
# Getting weather in city # 221 (acapulco)
# Getting weather in city # 222 (ahwa)
# Getting weather in city # 223 (dolbeau)
# City not found. Skipping...
# Getting weather in city # 224 (gumdag)
# Getting weather in city # 225 (dikson)
# Getting weather in city # 226 (severo-kurilsk)
# Getting weather in city # 227 (thompson)
# Getting weather in city # 228 (sibolga)
# Getting weather in city # 229 (kaputa)
# Getting weather in city # 230 (crab hill)
# City not found. Skipping...
# Getting weather in city # 231 (dinsor)
# City not found. Skipping...
# Getting weather in city # 232 (marcona)
# City not found. Skipping...
# Getting weather in city # 233 (yenagoa)
# Getting weather in city # 234 (northam)
# Getting weather in city # 235 (iqaluit)
# Getting weather in city # 236 (longyearbyen)
# Getting weather in city # 237 (torun)
# Getting weather in city # 238 (tiznit)
# Getting weather in city # 239 (kaitangata)
# Getting weather in city # 240 (high river)
# Getting weather in city # 241 (sorland)
# Getting weather in city # 242 (grand river south east)
# City not found. Skipping...
# Getting weather in city # 243 (fort-shevchenko)
# Getting weather in city # 244 (lolua)
# City not found. Skipping...
# Getting weather in city # 245 (port hedland)
# Getting weather in city # 246 (qaqortoq)
# Getting weather in city # 247 (muroto)
# Getting weather in city # 248 (saskylakh)
# Getting weather in city # 249 (paamiut)
# Getting weather in city # 250 (kudahuvadhoo)
# Getting weather in city # 251 (evanston)
# Getting weather in city # 252 (cherskiy)
# Getting weather in city # 253 (kerki)
# City not found. Skipping...
# Getting weather in city # 254 (port elizabeth)
# Getting weather in city # 255 (chuguyevka)
# Getting weather in city # 256 (lompoc)
# Getting weather in city # 257 (nevel)
# Getting weather in city # 258 (waingapu)
# Getting weather in city # 259 (clyde river)
# Getting weather in city # 260 (high prairie)
# Getting weather in city # 261 (rabo de peixe)
# Getting weather in city # 262 (sentyabrskiy)
# City not found. Skipping...
# Getting weather in city # 263 (talnakh)
# Getting weather in city # 264 (dillon)
# Getting weather in city # 265 (ajaccio)
# Getting weather in city # 266 (vanimo)
# Getting weather in city # 267 (bauchi)
# Getting weather in city # 268 (bobcaygeon)
# Getting weather in city # 269 (gundorovskiy)
# Getting weather in city # 270 (belomorsk)
# Getting weather in city # 271 (skalistyy)
# City not found. Skipping...
# Getting weather in city # 272 (union city)
# Getting weather in city # 273 (trapani)
# Getting weather in city # 274 (pitsunda)
# Getting weather in city # 275 (lasa)
# Getting weather in city # 276 (kamenskoye)
# City not found. Skipping...
# Getting weather in city # 277 (ust-ilimsk)
# Getting weather in city # 278 (sindal)
# Getting weather in city # 279 (palabuhanratu)
# City not found. Skipping...
# Getting weather in city # 280 (la palma)
# Getting weather in city # 281 (beloha)
# Getting weather in city # 282 (yeniseysk)
# Getting weather in city # 283 (santa cruz)
# Getting weather in city # 284 (dubbo)
# Getting weather in city # 285 (ozgon)
# City not found. Skipping...
# Getting weather in city # 286 (north platte)
# Getting weather in city # 287 (salalah)
# Getting weather in city # 288 (batemans bay)
# Getting weather in city # 289 (cayenne)
# Getting weather in city # 290 (mergui)
# City not found. Skipping...
# Getting weather in city # 291 (lithakia)
# Getting weather in city # 292 (bargal)
# City not found. Skipping...
# Getting weather in city # 293 (isoka)
# Getting weather in city # 294 (riviere-au-renard)
# Getting weather in city # 295 (faya)
# Getting weather in city # 296 (cody)
# Getting weather in city # 297 (alakurtti)
# Getting weather in city # 298 (caravelas)
# Getting weather in city # 299 (conchas)
# Getting weather in city # 300 (saldanha)
# Getting weather in city # 301 (the valley)
# Getting weather in city # 302 (comodoro rivadavia)
# Getting weather in city # 303 (inhambane)
# Getting weather in city # 304 (asau)
# Getting weather in city # 305 (havelock)
# Getting weather in city # 306 (tual)
# Getting weather in city # 307 (geraldton)
# Getting weather in city # 308 (diapaga)
# Getting weather in city # 309 (ust-nera)
# Getting weather in city # 310 (hasaki)
# Getting weather in city # 311 (solnechnyy)
# Getting weather in city # 312 (narsaq)
# Getting weather in city # 313 (umzimvubu)
# City not found. Skipping...
# Getting weather in city # 314 (lahaina)
# Getting weather in city # 315 (encheng)
# Getting weather in city # 316 (inongo)
# Getting weather in city # 317 (cam pha)
# City not found. Skipping...
# Getting weather in city # 318 (alta floresta)
# Getting weather in city # 319 (belushya guba)
# City not found. Skipping...
# Getting weather in city # 320 (umarkhed)
# Getting weather in city # 321 (getulio vargas)
# Getting weather in city # 322 (leua)
# Getting weather in city # 323 (saint anthony)
# Getting weather in city # 324 (road town)
# Getting weather in city # 325 (litoral del san juan)
# City not found. Skipping...
# Getting weather in city # 326 (kisangani)
# Getting weather in city # 327 (shenjiamen)
# Getting weather in city # 328 (lensk)
# Getting weather in city # 329 (liverpool)
# Getting weather in city # 330 (hambantota)
# Getting weather in city # 331 (petropavlovsk-kamchatskiy)
# Getting weather in city # 332 (boa vista)
# Getting weather in city # 333 (wamba)
# Getting weather in city # 334 (adrar)
# Getting weather in city # 335 (tanout)
# Getting weather in city # 336 (warqla)
# City not found. Skipping...
# Getting weather in city # 337 (sao filipe)
# Getting weather in city # 338 (pevek)
# Getting weather in city # 339 (otane)
# Getting weather in city # 340 (viedma)
# Getting weather in city # 341 (akonolinga)
# Getting weather in city # 342 (kaeo)
# Getting weather in city # 343 (kahului)
# Getting weather in city # 344 (pussi)
# Getting weather in city # 345 (trelew)
# Getting weather in city # 346 (imeni poliny osipenko)
# Getting weather in city # 347 (stornoway)
# Getting weather in city # 348 (svetlogorsk)
# Getting weather in city # 349 (taksimo)
# Getting weather in city # 350 (guerrero negro)
# Getting weather in city # 351 (barrow)
# Getting weather in city # 352 (olafsvik)
# Getting weather in city # 353 (shache)
# Getting weather in city # 354 (taoudenni)
# Getting weather in city # 355 (naron)
# Getting weather in city # 356 (townsville)
# Getting weather in city # 357 (macamic)
# Getting weather in city # 358 (lubango)
# Getting weather in city # 359 (kamenka)
# Getting weather in city # 360 (pacifica)
# Getting weather in city # 361 (rizhao)
# Getting weather in city # 362 (ondjiva)
# Getting weather in city # 363 (lorengau)
# Getting weather in city # 364 (korla)
# Getting weather in city # 365 (pochutla)
# Getting weather in city # 366 (manavgat)
# Getting weather in city # 367 (dawlatabad)
# Getting weather in city # 368 (turukhansk)
# Getting weather in city # 369 (batagay)
# Getting weather in city # 370 (byron bay)
# Getting weather in city # 371 (kalmunai)
# Getting weather in city # 372 (havoysund)
# Getting weather in city # 373 (novyy svit)
# Getting weather in city # 374 (xinmin)
# Getting weather in city # 375 (san francisco)
# Getting weather in city # 376 (faanui)
# Getting weather in city # 377 (baracoa)
# Getting weather in city # 378 (berasia)
# Getting weather in city # 379 (ekhabi)
# Getting weather in city # 380 (isangel)
# Getting weather in city # 381 (pundaguitan)
# Getting weather in city # 382 (palestina)
# Getting weather in city # 383 (itarema)
# Getting weather in city # 384 (vaitape)
# Getting weather in city # 385 (mehamn)
# Getting weather in city # 386 (marzuq)
# Getting weather in city # 387 (yeppoon)
# Getting weather in city # 388 (torbay)
# Getting weather in city # 389 (jhelum)
# Getting weather in city # 390 (tabiauea)
# City not found. Skipping...
# Getting weather in city # 391 (tazovskiy)
# Getting weather in city # 392 (trincomalee)
# Getting weather in city # 393 (lagoa)
# Getting weather in city # 394 (dwarka)
# Getting weather in city # 395 (uk)
# City not found. Skipping...
# Getting weather in city # 396 (vestmannaeyjar)
# Getting weather in city # 397 (tongchuan)
# Getting weather in city # 398 (babanusah)
# City not found. Skipping...
# Getting weather in city # 399 (touros)
# Getting weather in city # 400 (ulyanovo)
# City not found. Skipping...
# Getting weather in city # 401 (sinkat)
# City not found. Skipping...
# Getting weather in city # 402 (augusto correa)
# Getting weather in city # 403 (mathbaria)
# Getting weather in city # 404 (willmar)
# Getting weather in city # 405 (marawi)
# Getting weather in city # 406 (huimilpan)
# Getting weather in city # 407 (vanavara)
# Getting weather in city # 408 (kathmandu)
# Getting weather in city # 409 (cachoeira)
# Getting weather in city # 410 (nerchinskiy zavod)
# Getting weather in city # 411 (sept-iles)
# Getting weather in city # 412 (bambous virieux)
# Getting weather in city # 413 (los alamos)
# Getting weather in city # 414 (mount gambier)
# Getting weather in city # 415 (palmer)
# Getting weather in city # 416 (nangomba)
# Getting weather in city # 417 (goroka)
# Getting weather in city # 418 (palora)
# Getting weather in city # 419 (pontes e lacerda)
# Getting weather in city # 420 (chitungwiza)
# Getting weather in city # 421 (oktyabrskoye)
# Getting weather in city # 422 (abramovka)
# Getting weather in city # 423 (perbaungan)
# Getting weather in city # 424 (laguna)
# Getting weather in city # 425 (chuka)
# Getting weather in city # 426 (tabou)
# Getting weather in city # 427 (valparai)
# Getting weather in city # 428 (myitkyina)
# Getting weather in city # 429 (saint-georges)
# Getting weather in city # 430 (koungou)
# Getting weather in city # 431 (kloulklubed)
# Getting weather in city # 432 (broome)
# Getting weather in city # 433 (muros)
# Getting weather in city # 434 (thessalon)
# Getting weather in city # 435 (praia da vitoria)
# Getting weather in city # 436 (carutapera)
# Getting weather in city # 437 (ilhabela)
# Getting weather in city # 438 (tikrit)
# Getting weather in city # 439 (bereda)
# Getting weather in city # 440 (carman)
# Getting weather in city # 441 (fuzhou)
# Getting weather in city # 442 (soma)
# Getting weather in city # 443 (sitka)
# Getting weather in city # 444 (krasnoarmeysk)
# Getting weather in city # 445 (sao jose da coroa grande)
# Getting weather in city # 446 (brae)
# Getting weather in city # 447 (kuytun)
# Getting weather in city # 448 (tanete)
# Getting weather in city # 449 (filiatra)
# Getting weather in city # 450 (talara)
# Getting weather in city # 451 (halifax)
# Getting weather in city # 452 (lewisporte)
# Getting weather in city # 453 (kaitong)
# Getting weather in city # 454 (naze)
# Getting weather in city # 455 (beringovskiy)
# Getting weather in city # 456 (bowen)
# Getting weather in city # 457 (dindori)
# Getting weather in city # 458 (alofi)
# Getting weather in city # 459 (lerwick)
# Getting weather in city # 460 (coromandel)
# Getting weather in city # 461 (maghama)
# City not found. Skipping...
# Getting weather in city # 462 (roald)
# Getting weather in city # 463 (yar-sale)
# Getting weather in city # 464 (cedar city)
# Getting weather in city # 465 (umm kaddadah)
# Getting weather in city # 466 (kirakira)
# Getting weather in city # 467 (harper)
# Getting weather in city # 468 (komsomolets)
# Getting weather in city # 469 (hohhot)
# Getting weather in city # 470 (srednekolymsk)
# Getting weather in city # 471 (mon)
# Getting weather in city # 472 (rio gallegos)
# Getting weather in city # 473 (rio brilhante)
# Getting weather in city # 474 (tumannyy)
# City not found. Skipping...
# Getting weather in city # 475 (bardiyah)
# Getting weather in city # 476 (langsa)
# Getting weather in city # 477 (bonavista)
# Getting weather in city # 478 (sosnovo-ozerskoye)
# Getting weather in city # 479 (okha)
# Getting weather in city # 480 (osvaldo cruz)
# Getting weather in city # 481 (yakshur-bodya)
# City not found. Skipping...
# Getting weather in city # 482 (malatya)
# Getting weather in city # 483 (alice springs)
# Getting weather in city # 484 (okhotsk)
# Getting weather in city # 485 (amapa)
# Getting weather in city # 486 (port lincoln)
# Getting weather in city # 487 (pyatnitskoye)
# Getting weather in city # 488 (san cristobal)
# Getting weather in city # 489 (saint-joseph)
# Getting weather in city # 490 (tarbes)
# Getting weather in city # 491 (marigot)
# Getting weather in city # 492 (adana)
# Getting weather in city # 493 (uran)
# Getting weather in city # 494 (mitu)
# Getting weather in city # 495 (kupang)
# Getting weather in city # 496 (challapata)
# Getting weather in city # 497 (tuatapere)
# Getting weather in city # 498 (pasni)
# Getting weather in city # 499 (ucluelet)
# Getting weather in city # 500 (dunedin)
# Getting weather in city # 501 (limon)
# Getting weather in city # 502 (kentville)
# Getting weather in city # 503 (fria)
# Getting weather in city # 504 (oussouye)
# Getting weather in city # 505 (rudnogorsk)
# Getting weather in city # 506 (barkhan)
# Getting weather in city # 507 (nishihara)
# Getting weather in city # 508 (gornyy)
# Getting weather in city # 509 (altagracia de orituco)
# Getting weather in city # 510 (bubaque)
# Getting weather in city # 511 (bafq)
# Getting weather in city # 512 (grand-santi)
# Getting weather in city # 513 (puerto escondido)
# Getting weather in city # 514 (taltal)
# Getting weather in city # 515 (moerai)
# Getting weather in city # 516 (akdepe)
# Getting weather in city # 517 (lypova dolyna)
# Getting weather in city # 518 (mushie)
# Getting weather in city # 519 (bati)
# Getting weather in city # 520 (burnie)
# Getting weather in city # 521 (anadyr)
# Getting weather in city # 522 (spassk)
# Getting weather in city # 523 (biak)
# Getting weather in city # 524 (artyk)
# City not found. Skipping...
# Getting weather in city # 525 (ibotirama)
# Getting weather in city # 526 (yangambi)
# Getting weather in city # 527 (pangkalanbuun)
# Getting weather in city # 528 (bouna)
# Getting weather in city # 529 (tabora)
# Getting weather in city # 530 (udachnyy)
# Getting weather in city # 531 (sandovo)
# Getting weather in city # 532 (singaraja)
# Getting weather in city # 533 (hirara)
# Getting weather in city # 534 (higuey)
# City not found. Skipping...
# Getting weather in city # 535 (grand gaube)
# Getting weather in city # 536 (namibe)
# Getting weather in city # 537 (zaysan)
# Getting weather in city # 538 (taunggyi)
# Getting weather in city # 539 (camacha)
# Getting weather in city # 540 (yining)
# Getting weather in city # 541 (antofagasta)
# Getting weather in city # 542 (darnah)
# Getting weather in city # 543 (khani)
# Getting weather in city # 544 (bayburt)
# Getting weather in city # 545 (alugan)
# Getting weather in city # 546 (temir)
# Getting weather in city # 547 (usila)
# City not found. Skipping...
# Getting weather in city # 548 (fairview)
# Getting weather in city # 549 (chimore)
# Getting weather in city # 550 (nalut)
# Getting weather in city # 551 (tela)
# Getting weather in city # 552 (sinjar)
# Getting weather in city # 553 (de-kastri)
# Getting weather in city # 554 (mehran)
# Getting weather in city # 555 (chapais)
# Getting weather in city # 556 (sal rei)
# Getting weather in city # 557 (sinnamary)
# Getting weather in city # 558 (tautira)
# Getting weather in city # 559 (bima)
# Getting weather in city # 560 (farafangana)
# Getting weather in city # 561 (vila velha)
# Getting weather in city # 562 (luau)
# Getting weather in city # 563 (plastun)
# Getting weather in city # 564 (sika)
# Getting weather in city # 565 (ubinskoye)
# Getting weather in city # 566 (selikhino)
# Getting weather in city # 567 (bathsheba)
# Getting weather in city # 568 (ust-maya)
# Getting weather in city # 569 (cahors)
# Getting weather in city # 570 (abomsa)
# Getting weather in city # 571 (rocha)
# Getting weather in city # 572 (eydhafushi)
# Getting weather in city # 573 (ambulu)
# Getting weather in city # 574 (girvan)
# Getting weather in city # 575 (kavaratti)
# Getting weather in city # 576 (doctor pedro p. pena)
# City not found. Skipping...
# Getting weather in city # 577 (yayva)
# Getting weather in city # 578 (karaul)
# City not found. Skipping...
# Getting weather in city # 579 (nizhniy baskunchak)
# Getting weather in city # 580 (yatou)
# Getting weather in city # 581 (valparaiso)
# Getting weather in city # 582 (pombas)
# -------------------------------
# Weather Data Retrieval Complete
# Weather found for 533 out of 582 cities
# -------------------------------

# %% [markdown]
# #### Convert Raw Data to DataFrame
# * Export the city data into a csv file.
# * Display the DataFrame.
# * Display summary statistics for the DataFrame.

# %%
# Create and display a table with the weather data found above
raw_weather_data = pd.DataFrame({
    "City": cities,
    "Country": countries,
    "Latitude": stationlats,
    "Longitude": stationlngs,
    "Max Temp (F)": maxtemps,
    "Humidity (%)": humidities,
    "Cloudiness (%)": cloudiness,
    "Wind Speed (mph)": windspeeds,
    "Date (Unix)": dates
})
print("Weather data provided by OpenWeather")
raw_weather_data.head()
# Out:
# Weather data provided by OpenWeather
#      City Country  Latitude  Longitude  Max Temp (F)  Humidity (%)  \
# 0  omboue      GA   -1.5746     9.2618         79.45            76
# 1  kodiak      US   57.7900  -152.4072         42.39            94
# 2  hobart      AU  -42.8794   147.3294         43.05            79
# 3  nyurba      RU   63.2842   118.3319         34.50            89
# 4    chuy      UY  -33.6971   -53.4616         63.81            62
#
#    Cloudiness (%)  Wind Speed (mph)  Date (Unix)
# 0             100             11.34   1634646939
# 1             100             15.93   1634646940
# 2              20              1.01   1634646941
# 3              99             10.25   1634646942
# 4               0              4.59   1634646943

# %%
# Save data table to csv file
raw_weather_data.to_csv(output_data_file)
print(f"Raw weather data saved to: {output_data_file}")
# Out:
# Raw weather data saved to: output_data/cities.csv

# %%
# Display general statistics
print("Weather data provided by OpenWeather")
raw_weather_data.describe()
# Out:
# Weather data provided by OpenWeather
#          Latitude   Longitude  Max Temp (F)  Humidity (%)  Cloudiness (%)  \
# count  533.000000  533.000000    533.000000    533.000000      533.000000
# mean    20.983546   19.791698     61.458574     68.964353       55.437148
# std     33.048038   90.973882     21.939720     23.352896       40.325255
# min    -54.800000 -179.166700    -14.690000      4.000000        0.000000
# 25%     -5.198900  -59.335300     47.050000     55.000000       11.000000
# 50%     26.061400   25.086500     66.020000     75.000000       66.000000
# 75%     48.649900  100.354300     79.210000     87.000000      100.000000
# max     78.218600  179.316700    101.440000    100.000000      100.000000
#
#        Wind Speed (mph)   Date (Unix)
# count        533.000000  5.330000e+02
# mean           8.191520  1.634647e+09
# std            5.636205  1.449070e+02
# min            0.000000  1.634647e+09
# 25%            3.870000  1.634647e+09
# 50%            7.200000  1.634647e+09
# 75%           11.500000  1.634647e+09
# max           42.370000  1.634647e+09

# %% [markdown]
# #### Remove cities where humidity > 100% or cloudiness > 100%
# * This step is usually not necessary.
# * However, if any cities do have humidity or cloudiness > 100%, it indicates erroneous data, and those cities should be removed from the data set.

# %%
world_weather_data = raw_weather_data.loc[raw_weather_data["Humidity (%)"] <= 100]
world_weather_data = raw_weather_data.loc[raw_weather_data["Cloudiness (%)"] <= 100]
print("Weather data provided by OpenWeather")
world_weather_data.describe()
# Out:
# Weather data provided by OpenWeather
#          Latitude   Longitude  Max Temp (F)  Humidity (%)  Cloudiness (%)  \
# count  533.000000  533.000000    533.000000    533.000000      533.000000
# mean    20.983546   19.791698     61.458574     68.964353       55.437148
# std     33.048038   90.973882     21.939720     23.352896       40.325255
# min    -54.800000 -179.166700    -14.690000      4.000000        0.000000
# 25%     -5.198900  -59.335300     47.050000     55.000000       11.000000
# 50%     26.061400   25.086500     66.020000     75.000000       66.000000
# 75%     48.649900  100.354300     79.210000     87.000000      100.000000
# max     78.218600  179.316700    101.440000    100.000000      100.000000
#
#        Wind Speed (mph)   Date (Unix)
# count        533.000000  5.330000e+02
# mean           8.191520  1.634647e+09
# std            5.636205  1.449070e+02
# min            0.000000  1.634647e+09
# 25%            3.870000  1.634647e+09
# 50%            7.200000  1.634647e+09
# 75%           11.500000  1.634647e+09
# max           42.370000  1.634647e+09

# %% [markdown]
# ---
# ## Scatter Plots of World Cities Weather Data

# %% [markdown]
# #### Latitude vs. Temperature

# %%
# Convert Unix date to standard date
date = time.strftime("%m/%d/%y",time.gmtime(world_weather_data["Date (Unix)"].mean()))
print(f"World weather data was measured on {date}.")
# Out:
# World weather data was measured on 10/19/21.

# %%
# Create a scatter diagram from the weather data table using latitude and Max Temperature columns
plt.scatter(world_weather_data["Latitude"], world_weather_data["Max Temp (F)"], edgecolors = "black", c=-world_weather_data["Max Temp (F)"], cmap="RdBu")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({date})")
plt.grid()
plt.savefig("output_data/world_temps.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity

# %%
# Create a scatter diagram from the weather data table using latitude and Humidity columns
plt.scatter(world_weather_data["Latitude"], world_weather_data["Humidity (%)"], edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid()
plt.savefig("output_data/world_humidities.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness

# %%
# Create a scatter diagram from the weather data table using latitude and Cloudiness columns
plt.scatter(world_weather_data["Latitude"], world_weather_data["Cloudiness (%)"], edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid()
plt.savefig("output_data/world_cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed

# %%
# Create a scatter diagram from the weather data table using latitude and Wind Speed columns
plt.scatter(world_weather_data["Latitude"], world_weather_data["Wind Speed (mph)"], edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid()
plt.savefig("output_data/world_windspeeds.png")
plt.show()

# %% [markdown]
# ---
# ## Linear Regression Analysis of World Cities Weather Data

# %% [markdown]
# #### Divide weather data into Northern and Southern Hemispheres

# %%
# Divide world weather data into 2 tables (northern hemisphere and southern hemisphere)
northern_weather_data = world_weather_data.loc[world_weather_data["Latitude"] > 0]
southern_weather_data = world_weather_data.loc[world_weather_data["Latitude"] < 0]

# Check if any cities were dropped
northerncitycount = northern_weather_data["City"].count()
southerncitycount = southern_weather_data["City"].count()
totalcitycount = world_weather_data["City"].count()

# Print success/fail message with city counts
if northerncitycount + southerncitycount != totalcitycount:
    print("Weather data was divided into northern and southern hemispheres, however, one or more cities were dropped.")
    print(f"   Northern hemisphere data has {northerncitycount} cities.")
    print(f"   Southern hemisphere data has {southerncitycount} cities.")
    print(f"   Original data had {totalcitycount} cities.")
else:
    print("Weather data was successfully divided into northern and southern hemispheres.")
    print(f"   Northern hemisphere data has {northerncitycount} cities.")
    print(f"   Southern hemisphere data has {southerncitycount} cities.")
    print(f"   Original data has {totalcitycount} cities.")
# Out:
# Weather data was successfully divided into northern and southern hemispheres.
#    Northern hemisphere data has 373 cities.
#    Southern hemisphere data has 160 cities.
#    Original data has 533 cities.

# %% [markdown]
# ####  Northern Hemisphere:  Max Temp vs. Latitude

# %%
# Set region and data for analysis
region = "Northern Hemisphere"
x_data = northern_weather_data["Latitude"]
y_data = northern_weather_data["Max Temp (F)"]
outputfile = "output_data/northern_temps_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.min()+10))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.min()))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere:  Max Temp vs. Latitude

# %%
# Set region and data for analysis
region = "Southern Hemisphere"
x_data = southern_weather_data["Latitude"]
y_data = southern_weather_data["Max Temp (F)"]
outputfile = "output_data/southern_temps_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.max()-5))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.max()-10))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere:  Humidity vs. Latitude

# %%
# Set region and data for analysis
region = "Northern Hemisphere"
x_data = northern_weather_data["Latitude"]
y_data = northern_weather_data["Humidity (%)"]
outputfile = "output_data/northern_humidities_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.min()+10))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.min()))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere:  Humidity vs. Latitude

# %%
# Set region and data for analysis
region = "Southern Hemisphere"
x_data = southern_weather_data["Latitude"]
y_data = southern_weather_data["Humidity (%)"]
outputfile = "output_data/southern_humidities_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.min()+10))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.min()))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere:  Cloudiness vs. Latitude

# %%
# Set region and data for analysis
region = "Northern Hemisphere"
x_data = northern_weather_data["Latitude"]
y_data = northern_weather_data["Cloudiness (%)"]
outputfile = "output_data/northern_cloudiness_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.min()+10))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.min()))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere:  Cloudiness vs. Latitude

# %%
# Set region and data for analysis
region = "Southern Hemisphere"
x_data = southern_weather_data["Latitude"]
y_data = southern_weather_data["Cloudiness (%)"]
outputfile = "output_data/southern_cloudiness_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.min()+10))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.min()))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere:  Wind Speed vs. Latitude

# %%
# Set region and data for analysis
region = "Northern Hemisphere"
x_data = northern_weather_data["Latitude"]
y_data = northern_weather_data["Wind Speed (mph)"]
outputfile = "output_data/northern_windspeeds_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.max()-5))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.max()-10))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere:  Wind Speed vs. Latitude

# %%
# Set region and data for analysis
region = "Southern Hemisphere"
x_data = southern_weather_data["Latitude"]
y_data = southern_weather_data["Wind Speed (mph)"]
outputfile = "output_data/southern_windspeeds_analysis.png"

# Find the line of regression parameters
(m, b, r, p, stderr) = linregress(x_data, y_data)

# Create the line of regression data
y_regress = m * x_data + b

# Draw the scatter diagram
plt.scatter(x_data, y_data)
plt.xlabel(x_data.name)
plt.ylabel(y_data.name)
plt.title(f"{y_data.name} vs. {x_data.name} \n for {region} Cities on {date}")

# Draw the line of regression
plt.plot(x_data, y_regress, color="red")
plt.annotate(f"y = {m:.2f}x + {b:.2f}", color="red", xy=(x_data.min(),y_data.max()-5))
plt.annotate(f"r = {r:.2f}", color="red", xy=(x_data.min(),y_data.max()-10))

# Show diagram and save to file
plt.savefig(outputfile)
plt.show()
